# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("bike_sales_india.csv")

# %%
df.head(1)
# Out:
#        State  Avg Daily Distance (km)          Brand       Model  Price (INR)  \
# 0  Karnataka                    68.84  Royal Enfield  Hunter 350       252816
#
#    Year of Manufacture  Engine Capacity (cc) Fuel Type  Mileage (km/l)  \
# 0                 2021                   672  Electric           78.41
#
#   Owner Type  Registration Year Insurance Status Seller Type  \
# 0     Second               2024           Active  Individual
#
#    Resale Price (INR) City Tier
# 0           149934.18    Tier 3

# %%
df.tail(1)
# Out:
#             State  Avg Daily Distance (km)          Brand        Model  \
# 9999  West Bengal                    51.16  Royal Enfield  Classic 350
#
#       Price (INR)  Year of Manufacture  Engine Capacity (cc) Fuel Type  \
# 9999       323583                 2018                   529    Petrol
#
#       Mileage (km/l) Owner Type  Registration Year Insurance Status  \
# 9999           41.68     Second               2018          Expired
#
#      Seller Type  Resale Price (INR) City Tier
# 9999  Individual           142139.85    Tier 3

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   State                    10000 non-null  object
#  1   Avg Daily Distance (km)  10000 non-null  float64
#  2   Brand                    10000 non-null  object
#  3   Model                    10000 non-null  object
#  4   Price (INR)              10000 non-null  int64
#  5   Year of Manufacture      10000 non-null  int64
#  6   Engine Capacity (cc)     10000 non-null  int64
#  7   Fuel Type                10000 non-null  object
#  8   Mileage (km/l)           10000 non-null  float64
#  9   Owner Type               10000 non-null  object
#  10  Registration Year        10000 non-null  int64
#  11  Insurance Status         10000 non-null  object
#  12  Seller Type              10000 non-null  object
#  13  Resale Price (INR)       10000 non-null  float64
# ...

# %%
df.describe()
# Out:
#        Avg Daily Distance (km)    Price (INR)  Year of Manufacture  \
# count             10000.000000   10000.000000         10000.000000
# mean                 42.533128  224328.722400          2019.510500
# std                  21.676985  100753.660447             2.907668
# min                   5.010000   50031.000000          2015.000000
# 25%                  23.907500  137900.250000          2017.000000
# 50%                  42.480000  223878.000000          2019.000000
# 75%                  61.352500  311464.250000          2022.000000
# max                  80.000000  399981.000000          2024.000000
#
#        Engine Capacity (cc)  Mileage (km/l)  Registration Year  \
# count          10000.000000    10000.000000        10000.00000
# mean             552.695300       67.188926         2020.96510
# std              261.176292       20.891728            2.74897
# min              100.000000       25.000000         2015.00000
# ...

# %% [markdown]
# **Exploratory Data Analysis**

# %%
#Bivariate Analysis
sns.barplot(data=df, x="Year of Manufacture", y="Price (INR)" )
# Out:
# <Axes: xlabel='Year of Manufacture', ylabel='Price (INR)'>

# %%
#Observations:
#Based on manufacturing maximum price range is in year 2018
#Based on manufacturing minimum price range is in year 2020

# %%
#Univariak analysis
plt.figure(figsize=(5, 5))
plt.pie(seller_type_counts, labels=seller_type_counts.index, autopct='%1.1f%%', startangle=140, colors=sns.color_palette("viridis", len(seller_type_counts)))
# Out:
# ([<matplotlib.patches.Wedge at 0x1c3ed65ed80>,
# ...
#  [Text(-0.6977584470105707, -0.850372359396398, 'Dealer'),
#   Text(0.6977585266281741, 0.8503722940675337, 'Individual')],
#  [Text(-0.3805955165512203, -0.4638394687616716, '50.3%'),
#   Text(0.38059555997900396, 0.46383943312774556, '49.6%')])

# %%
##Observations:
#Dealers sell more bikes compared to individuals.

# %%
#Bivariate Analysis
sns.lineplot(data=df, x="Brand", y="Resale Price (INR)", color="red" )
# Out:
# <Axes: xlabel='Brand', ylabel='Resale Price (INR)'>

# %%
#Observations:
#Royal Enfield bikes generally have a higher resale value compared to others
# Lowest resale value company is Honda and KTM

# %%
#Univariak analysis
sns.histplot(data=df, x="Brand", color="red", edgecolor="black")
plt.title("Distribution of Brands")
plt.xlabel("Brands Nmae")
plt.ylabel("Count")
plt.show()

# %%
#Observations:
#Kawasaki is high popularity and highest sales brand as compares to others.
#baja and Honda is lowest sales brand

# %%
#Univariate analysis
sns.displot(data=df, x="Owner Type", color="pink")

# %%
#Observations:
#buyers highly prefer purchasing First Owner Type (new bikes)

# %%
#Univariak analysis
sns.countplot(data=df, y="State")
# Out:
# <Axes: xlabel='count', ylabel='State'>

# %%
#Observations:
#Punjab is one of the highest purchaser states for bikes in India.

# %%
sns.pairplot(data=df)

# %%
#Univariak analysis
sns.histplot(data=df, x="Fuel Type", color="brown")
# Out:
# <Axes: xlabel='Fuel Type', ylabel='Count'>

# %%
#Observations:
#Electric bike sales are low as compare to Hybrid bikes ans petrol bikes

# %%
#multivarible analysis
df.hist(bins=50, figsize=(20,15)) 
plt.show()

# %%
#Observations:
#Registration increase the every year.
#If price range is less then resaling bikes is high and resaling price is high then resaling bikes is less.
